# %% [markdown]
# # Import Libraries

# %%
import bs4
from bs4 import BeautifulSoup
from pathlib import Path
import polars as pl

# Check Version
print(f"BeautifulSoup Version: {bs4.__version__}")
# Out:
# BeautifulSoup Version: 4.14.3

# %% [markdown]
# # Load test file

# %%
html_file = Path("../data/source/alpha/alpha_week_2/02-2029_alpha_week_2.html") 

if html_file.exists():
    with open(html_file, "r", encoding="utf-8") as f:
        soup = BeautifulSoup(f, "lxml")
    
    for script_or_style in soup(["script", "style"]):
        script_or_style.decompose()

    raw_text = soup.get_text(separator="\n")
    lines = [line.strip() for line in raw_text.splitlines() if line.strip()]
    
    print(f"File loaded. {len(lines)} Rows found.")
else:
    print("File not found. Check the path.")
# Out:
# Datei geladen. 220 Textzeilen gefunden.

# %% [markdown]
# # Keywords and Results

# %%
# Define search keywords
keywords = ["Gold", "Cost", "Attack Damage", "Ability Power", "Health", "Movement Speed"]

# flag rows with keywords and store them for analysis
found_patterns = []

for line in lines:
    active_flags = [k for k in keywords if k.lower() in line.lower()]
    
    if active_flags:
        found_patterns.append({
            "text": line,
            "flags": active_flags
        })

# Display the first 20 matches for analysis
for p in found_patterns[:20]:
    print(f"[{', '.join(p['flags'])}] -> {p['text']}")
# Out:
# [Health] -> The Red teams health bars are no longer red but instead are the standard health color green with a red border.
# [Ability Power] -> Changed all tooltips that have dynamic ability power bonuses, so they now reflect the bonus in the tooltip properly
# [Ability Power] -> Decreased ability power, and removed mana bonus from Elixir of Brilliance
# [Cost] -> Reduced recipe cost of Abyssal Scepter
# [Health] -> Adjusted health regenration on Spirit Visage
# [Ability Power] -> Changed bonus damage on Zhonya's Ring of the Mindreamer to be Magical, instead of Physical, and reduced the amount of bonus ability power gained from killing champions
# [Health] -> Reduced the Health regeneration on Healing Potion
# [Ability Power] -> Reduced the Ability power gained from killing champions on Mejai's Soulstealer
# [Health] -> Added health regen to summoner spell "Rallying Banner"
# [Attack Damage] -> Reduced the attack damage and armor of Annie's bear Tibbers
# [Cost] -> Reduced the mana cost, and increased the "slow target" effect of Bowmaster's "Frost Shot"
# [Cost] -> Increased the duration, and reduced the mana cost of Judicator's "Eye for an Eye"
# [Health] -> Increased the Health bonus, but reduced the damage of the Summoner spell "Promote Minion"
# [Health] -> Health Potion
# [Health] -> Reduced the health of tower's in front of Inhibitors
# [Health] -> Reduced the health, attack range, and global experience for base towers
# [Health] -> Increased the health of far lane towers
# [Gold] -> Increased the gold gained from champion kills
# [Gold] -> Increased passive gold gain
# [Health] -> Reduced natural health and mana regenration
